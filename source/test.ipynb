# %%
import pandas as pd

# %%
food = pd.read_csv('data/전처리.csv')
food
# Out:
#        Unnamed: 0  식품종류            식품명   상세분류  1회 섭취량(g)     kcal 탄수화물(g)  \
# 0               0    음식           꿩불고기   육류구이      500.0    368.8    39.7
# 1               1    음식            닭갈비   육류구이      400.0   595.61    44.9
# 2               2    음식            닭갈비   육류구이      300.0   558.47    23.1
# 3               3    음식            닭꼬치   육류구이       70.0  176.723  13.348
# 4               4    음식           더덕구이  채소류구이      100.0    184.0    31.1
# ...           ...   ...            ...    ...        ...      ...     ...
# 52935       52935  가공식품       라임모히또 젤리    캔디류       70.0      264      61
# 52936       52936  가공식품       꼬마쮸 복숭아맛    캔디류       40.0      175      36
# 52937       52937  가공식품       올리렉스 로젠지    캔디류      120.0      300     120
# 52938       52938  가공식품         블루베리캔디    캔디류      100.0      390      97
# 52939       52939  가공식품  It's 무설탕 레몬캔디    캔디류       40.0      100      40
#
#        단백질(g)  지방(g)  당류(g)
# 0        33.5    8.5   16.9
# ...
